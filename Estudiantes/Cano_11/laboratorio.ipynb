# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Crear diccionarios para cada elemento
hidrogeno = {
    'Elemento': 'Hidrógeno',
    'Símbolo': 'H',
    'Número Atómico': 1,
    'Masa Atómica (u)': 1.008,
    'Punto de Fusión (K)': 14.01,
    'Punto de Ebullición (K)': 20.28,
    'Electronegatividad (Pauling)': 2.20
}

helio = {
    'Elemento': 'Helio',
    'Símbolo': 'He',
    'Número Atómico': 2,
    'Masa Atómica (u)': 4.0026,
    'Punto de Fusión (K)': 0.95,
    'Punto de Ebullición (K)': 4.22,
    'Electronegatividad (Pauling)': None
}

litio = {
    'Elemento': 'Litio',
    'Símbolo': 'Li',
    'Número Atómico': 3,
    'Masa Atómica (u)': 6.94,
    'Punto de Fusión (K)': 453.69,
    'Punto de Ebullición (K)': 1560,
    'Electronegatividad (Pauling)': 0.98
}

berilio = {
    'Elemento': 'Berilio',
    'Símbolo': 'Be',
    'Número Atómico': 4,
    'Masa Atómica (u)': 9.0122,
    'Punto de Fusión (K)': 1560,
    'Punto de Ebullición (K)': 2742,
    'Electronegatividad (Pauling)': 1.57
}

boro = {
    'Elemento': 'Boro',
    'Símbolo': 'B',
    'Número Atómico': 5,
    'Masa Atómica (u)': 10.81,
    'Punto de Fusión (K)': 2349,
    'Punto de Ebullición (K)': 4200,
    'Electronegatividad (Pauling)': 2.04
}

carbono = {
    'Elemento': 'Carbono',
    'Símbolo': 'C',
    'Número Atómico': 6,
    'Masa Atómica (u)': 12.011,
    'Punto de Fusión (K)': 3823,
    'Punto de Ebullición (K)': 4098,
    'Electronegatividad (Pauling)': 2.55
}

nitrogeno = {
    'Elemento': 'Nitrógeno',
    'Símbolo': 'N',
    'Número Atómico': 7,
    'Masa Atómica (u)': 14.007,
    'Punto de Fusión (K)': 63.15,
    'Punto de Ebullición (K)': 77.36,
    'Electronegatividad (Pauling)': 3.04
}

oxigeno = {
    'Elemento': 'Oxígeno',
    'Símbolo': 'O',
    'Número Atómico': 8,
    'Masa Atómica (u)': 15.999,
    'Punto de Fusión (K)': 54.36,
    'Punto de Ebullición (K)': 90.20,
    'Electronegatividad (Pauling)': 3.44
}

fluor = {
    'Elemento': 'Flúor',
    'Símbolo': 'F',
    'Número Atómico': 9,
    'Masa Atómica (u)': 18.998,
    'Punto de Fusión (K)': 53.53,
    'Punto de Ebullición (K)': 85.03,
    'Electronegatividad (Pauling)': 3.98
}

neon = {
    'Elemento': 'Neón',
    'Símbolo': 'Ne',
    'Número Atómico': 10,
    'Masa Atómica (u)': 20.180,
    'Punto de Fusión (K)': 24.56,
    'Punto de Ebullición (K)': 27.07,
    'Electronegatividad (Pauling)': None
}
df_elementos=pd.DataFrame([hidrogeno, helio, litio, berilio, boro, carbono, nitrogeno, oxigeno, fluor, neon])
df_elementos
# Out:
#     Elemento Símbolo  Número Atómico  Masa Atómica (u)  Punto de Fusión (K)  \
# 0  Hidrógeno       H               1            1.0080                14.01
# 1      Helio      He               2            4.0026                 0.95
# 2      Litio      Li               3            6.9400               453.69
# 3    Berilio      Be               4            9.0122              1560.00
# 4       Boro       B               5           10.8100              2349.00
# 5    Carbono       C               6           12.0110              3823.00
# 6  Nitrógeno       N               7           14.0070                63.15
# 7    Oxígeno       O               8           15.9990                54.36
# 8      Flúor       F               9           18.9980                53.53
# 9       Neón      Ne              10           20.1800                24.56
#
#    Punto de Ebullición (K)  Electronegatividad (Pauling)
# 0                    20.28                          2.20
# ...

# %%
a=df_elementos[['Elemento','Masa Atómica (u)']]
df_elementos[['Elemento','Masa Atómica (u)']]
# Out:
#     Elemento  Masa Atómica (u)
# 0  Hidrógeno            1.0080
# 1      Helio            4.0026
# 2      Litio            6.9400
# 3    Berilio            9.0122
# 4       Boro           10.8100
# 5    Carbono           12.0110
# 6  Nitrógeno           14.0070
# 7    Oxígeno           15.9990
# 8      Flúor           18.9980
# 9       Neón           20.1800

# %%
a[a['Masa Atómica (u)']>10]
# Out:
#     Elemento  Masa Atómica (u)
# 4       Boro            10.810
# 5    Carbono            12.011
# 6  Nitrógeno            14.007
# 7    Oxígeno            15.999
# 8      Flúor            18.998
# 9       Neón            20.180

# %%
b=df_elementos[['Elemento','Electronegatividad (Pauling)']]
c=b[b['Electronegatividad (Pauling)'].notnull()]
c
# Out:
#     Elemento  Electronegatividad (Pauling)
# 0  Hidrógeno                          2.20
# 2      Litio                          0.98
# 3    Berilio                          1.57
# 4       Boro                          2.04
# 5    Carbono                          2.55
# 6  Nitrógeno                          3.04
# 7    Oxígeno                          3.44
# 8      Flúor                          3.98

# %%
df_elementos['Masa Atómica (u)'].mean()
# Out:
# 11.296780000000002

# %%
print('Promedio de electrnegativiad:',c['Electronegatividad (Pauling)'].mean())
print('Desviacion estandar:',df_elementos['Electronegatividad (Pauling)'].std())
# Out:
# Promedio de electrnegativiad: 2.475
# Desviacion estandar: 0.9885053652574968

# %%
u=df_elementos['Punto de Fusión (K)'].max()
df_elementos[df_elementos['Punto de Fusión (K)'] >= u]
# Out:
#   Elemento Símbolo  Número Atómico  Masa Atómica (u)  Punto de Fusión (K)  \
# 5  Carbono       C               6            12.011               3823.0
#
#    Punto de Ebullición (K)  Electronegatividad (Pauling)
# 5                   4098.0                          2.55

# %%
i=df_elementos['Punto de Fusión (K)'].min()
df_elementos[df_elementos['Punto de Fusión (K)'] <= i]
# Out:
#   Elemento Símbolo  Número Atómico  Masa Atómica (u)  Punto de Fusión (K)  \
# 1    Helio      He               2            4.0026                 0.95
#
#    Punto de Ebullición (K)  Electronegatividad (Pauling)
# 1                     4.22                           NaN

# %%
dt=df_elementos[['Elemento','Masa Atómica (u)']]
dt.set_index('Elemento',inplace=True)

dt.plot(kind='bar')
plt.xlabel('elementos')
plt.ylabel('Masa Atómica (u)')
# Out:
# Text(0, 0.5, 'Masa Atómica (u)')

# %%
df_elementos.plot(kind='scatter',x='Electronegatividad (Pauling)',y='Masa Atómica (u)')
# Out:
# <Axes: xlabel='Electronegatividad (Pauling)', ylabel='Masa Atómica (u)'>

# %%
v=len(df_elementos.index)
temperatura_ambiente=25
df_prueba=df_elementos[df_elementos['Punto de Ebullición (K)'] >= temperatura_ambiente]
df_soldio=df_prueba[df_prueba['Punto de Fusión (K)'] > temperatura_ambiente]
df_liquidos=df_prueba[df_prueba['Punto de Fusión (K)'] <= temperatura_ambiente]
df_gases=df_elementos[df_elementos['Punto de Ebullición (K)'] <= temperatura_ambiente]

df_Solido=df_soldio.rename(columns={'Elemento': 'Elementos_solidos'})
df_Liquido=df_liquidos.rename(columns={'Elemento': 'Elementos_liquidos'})
df_Gases=df_gases.rename(columns={'Elemento': 'Elmentos_gaseosos'})

# %%
df_Solido
# Out:
#   Elementos_solidos Símbolo  Número Atómico  Masa Atómica (u)  \
# 2             Litio      Li               3            6.9400
# 3           Berilio      Be               4            9.0122
# 4              Boro       B               5           10.8100
# 5           Carbono       C               6           12.0110
# 6         Nitrógeno       N               7           14.0070
# 7           Oxígeno       O               8           15.9990
# 8             Flúor       F               9           18.9980
#
#    Punto de Fusión (K)  Punto de Ebullición (K)  Electronegatividad (Pauling)
# 2               453.69                  1560.00                          0.98
# 3              1560.00                  2742.00                          1.57
# 4              2349.00                  4200.00                          2.04
# 5              3823.00                  4098.00                          2.55
# 6                63.15                    77.36                          3.04
# ...

# %%
df_Liquido
# Out:
#   Elementos_liquidos Símbolo  Número Atómico  Masa Atómica (u)  \
# 9               Neón      Ne              10             20.18
#
#    Punto de Fusión (K)  Punto de Ebullición (K)  Electronegatividad (Pauling)
# 9                24.56                    27.07                           NaN

# %%
df_Gases
# Out:
#   Elmentos_gaseosos Símbolo  Número Atómico  Masa Atómica (u)  \
# 0         Hidrógeno       H               1            1.0080
# 1             Helio      He               2            4.0026
#
#    Punto de Fusión (K)  Punto de Ebullición (K)  Electronegatividad (Pauling)
# 0                14.01                    20.28                           2.2
# 1                 0.95                     4.22                           NaN

# %%
print('El promedipo de la masa de los elmentos en estado solido es de:', df_Solido['Masa Atómica (u)'].mean())
print('El promedipo de la masa de los elmentos en estado liquido es de:', df_Liquido['Masa Atómica (u)'].mean())
print('El promedipo de la masa de los elmentos en estado gaseoso es de:', df_Gases['Masa Atómica (u)'].mean())
# Out:
# El promedipo de la masa de los elmentos en estado solido es de: 12.539600000000002
# El promedipo de la masa de los elmentos en estado liquido es de: 20.18
# El promedipo de la masa de los elmentos en estado gaseoso es de: 2.5053

# %%
w={'Elementos':'Estado Solido', 'Masa':df_Solido['Masa Atómica (u)'].mean()}
ww={'Elementos':'Estado liquido', 'Masa':df_Liquido['Masa Atómica (u)'].mean()}
www={'Elementos':'Estado gaseoso','Masa':df_Gases['Masa Atómica (u)'].mean()}
dq = pd.DataFrame([w,ww,www])
dq.set_index('Elementos', inplace=True)
dq.plot(kind='bar')
plt.title('Comparacion')
plt.xlabel('Estado de la materia')
plt.ylabel('Promedio de la masa atomica')
plt.show()

# %%
data = [
    {
        'Partícula': 'Electrón',
        'Masa (MeV/c^2)': 0.511,
        'Carga (e)': -1,
        'Spin': '1/2',
        'Tiempo de Vida Media (s)': '6.6 x 10^29',
        'Interacción Fundamental': 'Electromagnética'
    },
    {
        'Partícula': 'Protón',
        'Masa (MeV/c^2)': 938.272,
        'Carga (e)': +1,
        'Spin': '1/2',
        'Tiempo de Vida Media (s)': 'Estable',
        'Interacción Fundamental': 'Electromagnética, Fuerte'
    },
    {
        'Partícula': 'Neutrón',
        'Masa (MeV/c^2)': 939.565,
        'Carga (e)': 0,
        'Spin': '1/2',
        'Tiempo de Vida Media (s)': '881.5',
        'Interacción Fundamental': 'Fuerte, Débil'
    },
    {
        'Partícula': 'Muón',
        'Masa (MeV/c^2)': 105.658,
        'Carga (e)': -1,
        'Spin': '1/2',
        'Tiempo de Vida Media (s)': '2.2 x 10^-6',
        'Interacción Fundamental': 'Electromagnética'
    },
    {
        'Partícula': 'Pión (+)',
        'Masa (MeV/c^2)': 139.570,
        'Carga (e)': +1,
        'Spin': '0',
        'Tiempo de Vida Media (s)': '2.6 x 10^-8',
        'Interacción Fundamental': 'Fuerte'
    },
    {
        'Partícula': 'Pión (0)',
        'Masa (MeV/c^2)': 134.977,
        'Carga (e)': 0,
        'Spin': '0',
        'Tiempo de Vida Media (s)': '8.4 x 10^-17',
        'Interacción Fundamental': 'Fuerte'
    },
    {
        'Partícula': 'Pión (-)',
        'Masa (MeV/c^2)': 139.570,
        'Carga (e)': -1,
        'Spin': '0',
        'Tiempo de Vida Media (s)': '2.6 x 10^-8',
        'Interacción Fundamental': 'Fuerte'
    },
    {
        'Partícula': 'Kaón (K+)',
        'Masa (MeV/c^2)': 493.677,
        'Carga (e)': +1,
        'Spin': '0',
        'Tiempo de Vida Media (s)': '1.24 x 10^-8',
        'Interacción Fundamental': 'Fuerte'
    },
    {
        'Partícula': 'Kaón (K0)',
        'Masa (MeV/c^2)': 497.611,
        'Carga (e)': 0,
        'Spin': '0',
        'Tiempo de Vida Media (s)': '5.1 x 10^-8',
        'Interacción Fundamental': 'Fuerte'
    }
]
df_particulas=pd.DataFrame(data)
df_particulas
# Out:
#    Partícula  Masa (MeV/c^2)  Carga (e) Spin Tiempo de Vida Media (s)  \
# 0   Electrón           0.511         -1  1/2              6.6 x 10^29
# 1     Protón         938.272          1  1/2                  Estable
# 2    Neutrón         939.565          0  1/2                    881.5
# 3       Muón         105.658         -1  1/2              2.2 x 10^-6
# 4   Pión (+)         139.570          1    0              2.6 x 10^-8
# 5   Pión (0)         134.977          0    0             8.4 x 10^-17
# 6   Pión (-)         139.570         -1    0              2.6 x 10^-8
# 7  Kaón (K+)         493.677          1    0             1.24 x 10^-8
# 8  Kaón (K0)         497.611          0    0              5.1 x 10^-8
#
#     Interacción Fundamental
# 0          Electromagnética
# 1  Electromagnética, Fuerte
# 2             Fuerte, Débil
# 3          Electromagnética
# 4                    Fuerte
# 5                    Fuerte
# 6                    Fuerte
# 7                    Fuerte
# ...

# %%
plt.figure(figsize=(5,5))
df_particulas.plot(x='Tiempo de Vida Media (s)', y='Masa (MeV/c^2)',kind='scatter')
plt.xlabel('Tiempo de vida')
plt.ylabel('masa')
plt.title('Masa en funcion del tiempo')
plt.show()

# %%
plt.figure(figsize=(5,5))
df_particulas.plot(x='Masa (MeV/c^2)',y='Carga (e)',kind='scatter')
plt.xlabel('masa de la particula')
plt.ylabel('carga de la particula')
plt.title('CARGA DE LA PARTICULA EN FUNCION DE LA MASA')
plt.show()

# %%
df_particulas['Masa (MeV/c^2)'].mean()
# Out:
# 376.60122222222225

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-2ddf366a04e3> in <cell line: 1>()
# ----> 1 df_matriz2.corr()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10702         cols = data.columns
#   10703         idx = cols.copy()
# > 10704         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10705
#   10706         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1887         if dtype is not None:
#    1888             dtype = np.dtype(dtype)
# -> 1889         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890         if result.dtype is not dtype:
#    1891             result = np.array(result, dtype=dtype, copy=False)
#
# ...
